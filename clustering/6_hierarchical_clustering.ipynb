# %% [markdown]
# # Hierarchical Clustering

# %% [markdown]
# **Hierarchical clustering** refers to a class of clustering methods that seek to build a **hierarchy** of clusters, in which some clusters contain others. In this assignment, we will explore a top-down approach, recursively bipartitioning the data using k-means.

# %% [markdown]
# ## Import packages

# %% [markdown]
# The following code block will check if you have the correct version of GraphLab Create. Any version later than 1.8.5 will do. To upgrade, read [this page](https://turi.com/download/upgrade-graphlab-create.html).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import time
from scipy.sparse import csr_matrix
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances
from sklearn.preprocessing import normalize
# %matplotlib inline

# %% [markdown]
# ## Load the Wikipedia dataset

# %%
wiki = pd.read_csv('people_wiki.csv')

# %% [markdown]
# As we did in previous assignments, let's extract the TF-IDF features:

# %%
def load_sparse_csr(filename):
    loader = np.load(filename)
    data = loader['data']
    indices = loader['indices']
    indptr = loader['indptr']
    shape = loader['shape']
    
    return csr_matrix( (data, indices, indptr), shape)

tf_idf = load_sparse_csr('people_wiki_tf_idf.npz')
map_index_to_word = pd.read_json('people_wiki_map_index_to_word.json',typ='series')
#word to index

# %%
map_index_to_word.index[193434]
# Out:
# u'fazul'

# %% [markdown]
# To run k-means on this dataset, we should convert the data matrix into a sparse matrix.

# %% [markdown]
# To be consistent with the k-means assignment, let's normalize all vectors to have unit norm.

# %%
from sklearn.preprocessing import normalize
tf_idf = normalize(tf_idf)

# %% [markdown]
# ## Bipartition the Wikipedia dataset using k-means

# %% [markdown]
# Recall our workflow for clustering text data with k-means:
#
# 1. Load the dataframe containing a dataset, such as the Wikipedia text dataset.
# 2. Extract the data matrix from the dataframe.
# 3. Run k-means on the data matrix with some value of k.
# 4. Visualize the clustering results using the centroids, cluster assignments, and the original dataframe. We keep the original dataframe around because the data matrix does not keep auxiliary information (in the case of the text dataset, the title of each article).
#
# Let us modify the workflow to perform bipartitioning:
#
# 1. Load the dataframe containing a dataset, such as the Wikipedia text dataset.
# 2. Extract the data matrix from the dataframe.
# 3. Run k-means on the data matrix with k=2.
# 4. Divide the data matrix into two parts using the cluster assignments.
# 5. Divide the dataframe into two parts, again using the cluster assignments. This step is necessary to allow for visualization.
# 6. Visualize the bipartition of data.
#
# We'd like to be able to repeat Steps 3-6 multiple times to produce a **hierarchy** of clusters such as the following:
# ```
#                       (root)
#                          |
#             +------------+-------------+
#             |                          |
#          Cluster                    Cluster
#      +------+-----+             +------+-----+
#      |            |             |            |
#    Cluster     Cluster       Cluster      Cluster
# ```
# Each **parent cluster** is bipartitioned to produce two **child clusters**. At the very top is the **root cluster**, which consists of the entire dataset.
#
# Now we write a wrapper function to bipartition a given cluster using k-means. There are three variables that together comprise the cluster:
#
# * `dataframe`: a subset of the original dataframe that correspond to member rows of the cluster
# * `matrix`: same set of rows, stored in sparse matrix format
# * `centroid`: the centroid of the cluster (not applicable for the root cluster)
#
# Rather than passing around the three variables separately, we package them into a Python dictionary. The wrapper function takes a single dictionary (representing a parent cluster) and returns two dictionaries (representing the child clusters).

# %%
def bipartition(cluster, maxiter=400, num_runs=4, seed=None):
    '''cluster: should be a dictionary containing the following keys
                * dataframe: original dataframe
                * matrix:    same data, in matrix format
                * centroid:  centroid for this particular cluster'''
    
    data_matrix = cluster['matrix']
    dataframe   = cluster['dataframe']
    
    # Run k-means on the data matrix with k=2. We use scikit-learn here to simplify workflow.
    kmeans_model = KMeans(n_clusters=2, max_iter=maxiter, n_init=num_runs, random_state=seed, n_jobs=-1, verbose=1)
    kmeans_model.fit(data_matrix)
    centroids, cluster_assignment = kmeans_model.cluster_centers_, kmeans_model.labels_
    
    # Divide the data matrix into two parts using the cluster assignments.
    data_matrix_left_child, data_matrix_right_child = data_matrix[cluster_assignment==0], \
                                                      data_matrix[cluster_assignment==1]
    
    # Divide the dataframe into two parts, again using the cluster assignments.
    cluster_assignment_sa = np.array(cluster_assignment) # minor format conversion
    dataframe_left_child, dataframe_right_child     = dataframe[cluster_assignment_sa==0], \
                                                      dataframe[cluster_assignment_sa==1]
        
    
    # Package relevant variables for the child clusters
    cluster_left_child  = {'matrix': data_matrix_left_child,
                           'dataframe': dataframe_left_child,
                           'centroid': centroids[0]}
    cluster_right_child = {'matrix': data_matrix_right_child,
                           'dataframe': dataframe_right_child,
                           'centroid': centroids[1]}
    
    return (cluster_left_child, cluster_right_child)

# %% [markdown]
# The following cell performs bipartitioning of the Wikipedia dataset. Allow 20-60 seconds to finish.
#
# Note. For the purpose of the assignment, we set an explicit seed (`seed=1`) to produce identical outputs for every run. In pratical applications, you might want to use different random seeds for all runs.

# %%
wiki_data = {'matrix': tf_idf, 'dataframe': wiki} # no 'centroid' for the root cluster
left_child, right_child = bipartition(wiki_data, maxiter=100, num_runs=6, seed=1)
# Out:
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Iteration  0, inertia 116092.674
# Iteration  0, inertia 116351.246
# Iteration  0, inertia 116293.919
# Iteration  0, inertia 116101.162
# Iteration  1, inertia 58254.170
# Iteration  1, inertia 58294.624
# Iteration  1, inertia 58271.393
# Iteration  1, inertia 58247.691
# Iteration  2, inertia 58230.098
# Iteration  2, inertia 58233.830
# Iteration  2, inertia 58242.910
# Iteration  2, inertia 58228.673
# Iteration  3, inertia 58226.274
# Iteration  3, inertia 58227.713
# Iteration  3, inertia 58232.422
# Iteration  3, inertia 58225.418
# Iteration  4, inertia 58224.964
# Iteration  4, inertia 58226.204
# Iteration  4, inertia 58228.131
# Iteration  4, inertia 58224.401
# Iteration  5, inertia 58224.668
# Iteration  5, inertia 58225.580
# Iteration  5, inertia 58226.902
# Iteration  5, inertia 58223.619
# Iteration  6, inertia 58224.616
# Iteration  6, inertia 58225.205
# Iteration  6, inertia 58222.908
# Iteration  6, inertia 58226.284
# Iteration  7, inertia 58224.605
# Iteration  7, inertia 58224.853
# Iteration  7, inertia 58222.306
# Iteration  7, inertia 58225.813
# Iteration  8, inertia 58224.601
# Iteration  8, inertia 58224.350
# Iteration  8, inertia 58221.836
# Iteration  8, inertia 58225.397
# Iteration  9, inertia 58224.600
# Iteration  9, inertia 58223.410
# Iteration  9, inertia 58221.480
# Iteration  9, inertia 58225.087
# Iteration 10, inertia 58224.599
# Iteration 10, inertia 58222.036
# Iteration 10, inertia 58224.880
# Iteration 10, inertia 58221.139
# Iteration 11, inertia 58224.599
# Iteration 11, inertia 58220.745
# Iteration 11, inertia 58224.759
# Iteration 11, inertia 58220.829
# Iteration 12, inertia 58224.598
# Iteration 12, inertia 58219.861
# Iteration 12, inertia 58224.689
# Iteration 12, inertia 58220.507
# Iteration 13, inertia 58224.598
# Iteration 13, inertia 58219.330
# Iteration 13, inertia 58224.650
# Iteration 13, inertia 58220.123
# Iteration 14, inertia 58224.597
# Iteration 14, inertia 58219.051
# Iteration 14, inertia 58224.630
# Iteration 14, inertia 58219.676
# Iteration 15, inertia 58224.597
# Iteration 15, inertia 58218.902
# Iteration 15, inertia 58224.619
# Iteration 15, inertia 58219.119
# Iteration 16, inertia 58224.597
# Iteration 16, inertia 58218.813
# Iteration 16, inertia 58224.614
# Iteration 16, inertia 58218.385
# Iteration 17, inertia 58224.597
# Iteration 17, inertia 58218.762
# Iteration 17, inertia 58224.609
# Iteration 17, inertia 58217.228
# Iteration 18, inertia 58224.597
# Iteration 18, inertia 58218.726
# Iteration 18, inertia 58224.606
# Iteration 18, inertia 58215.436
# Iteration 19, inertia 58224.596
# Iteration 19, inertia 58218.700
# Iteration 19, inertia 58224.604
# Iteration 19, inertia 58212.832
# Iteration 20, inertia 58224.596
# Converged at iteration 20: center shift 0.000000e+00 within tolerance 1.803739e-10
# Initialization complete
# Iteration 20, inertia 58218.680
# Iteration 20, inertia 58224.602
# Iteration 20, inertia 58207.937
# Iteration  0, inertia 116055.640
# Iteration 21, inertia 58218.666
# Iteration 21, inertia 58224.601
# Iteration 21, inertia 58197.012
# Iteration  1, inertia 58271.522
# Iteration 22, inertia 58218.657
# Iteration 22, inertia 58224.601
# Iteration 22, inertia 58181.631
# Iteration  2, inertia 58237.193
# Iteration 23, inertia 58218.652
# Iteration 23, inertia 58224.600
# Iteration 23, inertia 58179.851
# Iteration  3, inertia 58233.059
# Iteration 24, inertia 58218.649
# Iteration 24, inertia 58224.600
# Iteration 24, inertia 58179.683
# Iteration  4, inertia 58230.830
# Iteration 25, inertia 58218.647
# Iteration 25, inertia 58224.600
# Iteration 25, inertia 58179.627
# Iteration  5, inertia 58229.169
# Iteration 26, inertia 58218.645
# Iteration 26, inertia 58224.600
# Iteration 26, inertia 58179.602
# Iteration  6, inertia 58228.009
# Iteration 27, inertia 58218.644
# Iteration 27, inertia 58224.599
# Iteration 27, inertia 58179.589
# Iteration  7, inertia 58227.317
# Iteration 28, inertia 58218.643
# Iteration 28, inertia 58224.599
# Converged at iteration 28: center shift 0.000000e+00 within tolerance 1.803739e-10
# Initialization complete
# Iteration 28, inertia 58179.584
# Iteration  8, inertia 58226.845
# Iteration 29, inertia 58218.643
# Iteration  0, inertia 116225.092
# Iteration 29, inertia 58179.581
# Iteration  9, inertia 58226.511
# Iteration 30, inertia 58218.642
# Iteration  1, inertia 58292.017
# Iteration 30, inertia 58179.579
# Iteration 10, inertia 58226.197
# Iteration 31, inertia 58218.642
# Iteration  2, inertia 58233.584
# Iteration 31, inertia 58179.577
# Iteration 11, inertia 58225.747
# Iteration 32, inertia 58218.642
# Iteration  3, inertia 58229.950
# Iteration 32, inertia 58179.576
# Iteration 12, inertia 58225.095
# Iteration 33, inertia 58218.642
# Converged at iteration 33: center shift 0.000000e+00 within tolerance 1.803739e-10
# Iteration  4, inertia 58228.011
# Iteration 33, inertia 58179.575
# Iteration 13, inertia 58224.739
# Iteration  5, inertia 58226.660
# Iteration 34, inertia 58179.575
# Iteration 14, inertia 58224.646
# Iteration  6, inertia 58226.037
# Iteration 35, inertia 58179.575
# Converged at iteration 35: center shift 0.000000e+00 within tolerance 1.803739e-10
# Iteration 15, inertia 58224.616
# Iteration  7, inertia 58225.578
# Iteration 16, inertia 58224.605
# Iteration  8, inertia 58225.219
# Iteration 17, inertia 58224.600
# Iteration  9, inertia 58224.971
# Iteration 18, inertia 58224.598
# Iteration 10, inertia 58224.808
# Iteration 19, inertia 58224.597
# Iteration 11, inertia 58224.719
# Iteration 20, inertia 58224.596
# Iteration 12, inertia 58224.666
# Iteration 21, inertia 58224.596
# Iteration 13, inertia 58224.635
# Iteration 22, inertia 58224.595
# Iteration 14, inertia 58224.623
# Iteration 23, inertia 58224.595
# Iteration 15, inertia 58224.615
# Iteration 24, inertia 58224.595
# Converged at iteration 24: center shift 0.000000e+00 within tolerance 1.803739e-10
# Iteration 16, inertia 58224.610
# Iteration 17, inertia 58224.607
# Iteration 18, inertia 58224.604
# Iteration 19, inertia 58224.603
# Iteration 20, inertia 58224.602
# Iteration 21, inertia 58224.601
# Iteration 22, inertia 58224.601
# Iteration 23, inertia 58224.600
# Iteration 24, inertia 58224.600
# Converged at iteration 24: center shift 0.000000e+00 within tolerance 1.803739e-10

# %% [markdown]
# Let's examine the contents of one of the two clusters, which we call the `left_child`, referring to the tree visualization above.

# %%
left_child
# Out:
# {'centroid': array([  0.00000000e+00,   8.57526623e-06,   0.00000000e+00, ...,
#           1.38560691e-04,   6.46049863e-05,   2.26551103e-05]),
#  'dataframe':                                                      URI  \
#  0            <http://dbpedia.org/resource/Digby_Morrell>
#  17     <http://dbpedia.org/resource/Paddy_Dunne_(Gael...
#  21           <http://dbpedia.org/resource/Ceiron_Thomas>
#  22            <http://dbpedia.org/resource/Adel_Sellimi>
#  25             <http://dbpedia.org/resource/Vic_Stasiuk>
#  28            <http://dbpedia.org/resource/Leon_Hapgood>
#  30               <http://dbpedia.org/resource/Dom_Flora>
#  33               <http://dbpedia.org/resource/Bob_Reece>
#  41     <http://dbpedia.org/resource/Bob_Adams_(Americ...
#  48              <http://dbpedia.org/resource/Marc_Logan>
#  49          <http://dbpedia.org/resource/Corey_Woolfolk>
#  63              <http://dbpedia.org/resource/Alan_Roper>
#  75      <http://dbpedia.org/resource/Vladimir_Yurchenko>
#  78           <http://dbpedia.org/resource/Doug_McIntosh>
#  92            <http://dbpedia.org/resource/Shaka_Hislop>
#  95            <http://dbpedia.org/resource/Steve_Castle>
#  99              <http://dbpedia.org/resource/Dean_Greig>
#  101    <http://dbpedia.org/resource/James_Stewart_(Am...
#  102       <http://dbpedia.org/resource/Fredrik_Jacobson>
#  105     <http://dbpedia.org/resource/Juan_Pablo_Montoya>
#  114            <http://dbpedia.org/resource/Al_Hairston>
#  116             <http://dbpedia.org/resource/Ron_Shuman>
#  118    <http://dbpedia.org/resource/Bill_Young_(Austr...
#  122    <http://dbpedia.org/resource/Se%C3%A1n_%C3%93g...
#  123        <http://dbpedia.org/resource/Mike_Trebilcock>
#  137          <http://dbpedia.org/resource/Daniel_Falzon>
#  145          <http://dbpedia.org/resource/Cameron_Sharp>
#  151              <http://dbpedia.org/resource/Gary_Fila>
#  152    <http://dbpedia.org/resource/Roger_James_(foot...
#  153      <http://dbpedia.org/resource/Aled_de_Malmanche>
#  ...                                                  ...
#  58932  <http://dbpedia.org/resource/Kevin_Clark_(bask...
#  58933         <http://dbpedia.org/resource/Justin_Huish>
#  58940           <http://dbpedia.org/resource/Lamar_King>
#  58941        <http://dbpedia.org/resource/Tyler_Lockett>
#  58943    <http://dbpedia.org/resource/Bernadette_Benson>
#  58944        <http://dbpedia.org/resource/Blake_Russell>
#  58949           <http://dbpedia.org/resource/Marc_Sneyd>
#  58950           <http://dbpedia.org/resource/John_Arigo>
#  58954         <http://dbpedia.org/resource/Paul_Foytack>
#  58960     <http://dbpedia.org/resource/Sergey_Erzrumyan>
#  58962  <http://dbpedia.org/resource/David_Leslie_(rug...
#  58968            <http://dbpedia.org/resource/Kurt_Luby>
#  58969         <http://dbpedia.org/resource/Ray_Daviault>
#  58982  <http://dbpedia.org/resource/Jeff_Gray_(baseba...
#  58985  <http://dbpedia.org/resource/Craig_Davis_(Aust...
#  58987         <http://dbpedia.org/resource/Mike_Bruhert>
#  58988         <http://dbpedia.org/resource/Jack_Swagger>
#  58992             <http://dbpedia.org/resource/Jim_Eddy>
#  58993  <http://dbpedia.org/resource/Edgar_Renter%C3%ADa>
#  59003    <http://dbpedia.org/resource/Beth_Dunkenberger>
#  59007            <http://dbpedia.org/resource/Brad_Huse>
#  59010         <http://dbpedia.org/resource/Kaid_Mohamed>
#  59018  <http://dbpedia.org/resource/Jim_Casey_(footba...
#  59026  <http://dbpedia.org/resource/Richard_Thompson_...
#  59028         <http://dbpedia.org/resource/Eric_Naposki>
#  59051     <http://dbpedia.org/resource/Geoffrey_Kipsang>
#  59052         <http://dbpedia.org/resource/Dave_Nilsson>
#  59065  <http://dbpedia.org/resource/Dee_Brown_(basket...
#  59068  <http://dbpedia.org/resource/David_Cass_(footb...
#  59069          <http://dbpedia.org/resource/Keith_Elias>
#
#                                             name  \
#  0                                 Digby Morrell
#  17              Paddy Dunne (Gaelic footballer)
#  21                                Ceiron Thomas
#  22                                 Adel Sellimi
#  25                                  Vic Stasiuk
#  28                                 Leon Hapgood
#  30                                    Dom Flora
#  33                                    Bob Reece
#  41                Bob Adams (American football)
#  48                                   Marc Logan
#  49                               Corey Woolfolk
#  63                                   Alan Roper
#  75                           Vladimir Yurchenko
#  78                                Doug McIntosh
#  92                                 Shaka Hislop
#  95                                 Steve Castle
#  99                                   Dean Greig
#  101           James Stewart (American football)
#  102                            Fredrik Jacobson
#  105                          Juan Pablo Montoya
#  114                                 Al Hairston
#  116                                  Ron Shuman
#  118    Bill Young (Australian rules footballer)
#  122       Se%C3%A1n %C3%93g %C3%93 hAilp%C3%ADn
#  123                             Mike Trebilcock
#  137                               Daniel Falzon
#  145                               Cameron Sharp
#  151                                   Gary Fila
#  152                    Roger James (footballer)
#  153                           Aled de Malmanche
#  ...                                         ...
#  58932                  Kevin Clark (basketball)
#  58933                              Justin Huish
#  58940                                Lamar King
#  58941                             Tyler Lockett
#  58943                         Bernadette Benson
#  58944                             Blake Russell
#  58949                                Marc Sneyd
#  58950                                John Arigo
#  58954                              Paul Foytack
#  58960                          Sergey Erzrumyan
#  58962                David Leslie (rugby union)
#  58968                                 Kurt Luby
#  58969                              Ray Daviault
#  58982           Jeff Gray (baseball, born 1963)
#  58985       Craig Davis (Australian footballer)
#  58987                              Mike Bruhert
#  58988                              Jack Swagger
#  58992                                  Jim Eddy
#  58993                       Edgar Renter%C3%ADa
#  59003                         Beth Dunkenberger
#  59007                                 Brad Huse
#  59010                              Kaid Mohamed
#  59018                    Jim Casey (footballer)
#  59026  Richard Thompson (footballer, born 1969)
#  59028                              Eric Naposki
#  59051                          Geoffrey Kipsang
#  59052                              Dave Nilsson
#  59065         Dee Brown (basketball, born 1968)
#  59068                   David Cass (footballer)
#  59069                               Keith Elias
#
#                                                      text
#  0      digby morrell born 10 october 1979 is a former...
#  17     paddy dunne was a gaelic football player from ...
#  21     ceiron thomas born 23 october 1983 is a welsh ...
#  22     adel sellimi arabic was born on 16 november 19...
#  25     victor john stasiuk born may 23 1929 is a reti...
#  28     leon duane hapgood born 7 august 1979is an eng...
#  30     dominick a dom flora born june 12 1935 is an a...
#  33     robert scott reece born january 5 1951 is an a...
#  41     robert bruce bob adams born august 15 1946 in ...
#  48     marc anthony logan born may 9 1965 is a former...
#  49     corey woolfolk born february 26 1983 in ann ar...
#  63     alan roper born may 1939 in tipton staffordshi...
#  75     uladzimir vasilyevich yurchanka belarusian rus...
#  78     doug mcinstosh is a retired american basketbal...
#  92     neil shaka hislop cm born 22 february 1969 is ...
#  95     steve castle born 17 may 1966 in barking is a ...
#  99     dean greig born 31 october 1968 is a former au...
#  101    james ottis stewart born december 27 1971 is a...
#  102    fredrik ulf yngve jacobson born 26 september 1...
#  105    juan pablo montoya roldn born september 20 197...
#  114    alan leroy al hairston born december 11 1945 i...
#  116    ron shuman born september 15 1952 is an americ...
#  118    william d bill young born 6 june 1931 is a for...
#  122    sen g hailpn born 22 may 1977 is a fijianirish...
#  123    michael mike trebilcock born 29 november 1944 ...
#  137    daniel lawson falzon born 16 march 1994 is a p...
#  145    robert cameron sharp born 3 june 1958 is a sco...
#  151    gary fila born 18 november 1981 is australian ...
#  152    roger james born 21 october 1975 is a former a...
#  153    aled peter de malmanche born 11 september 1984...
#  ...                                                  ...
#  58932  kevin clark is an assistant mens basketball co...
#  58933  justin huish is an american double olympic cha...
#  58940  lamar king born august 10 1975 is a former ame...
#  58941  tyler lockett born september 28 1992 is an ame...
#  58943  bernadette benson is a canadian born athlete s...
#  58944  blake russell ne phillips born july 24 1975 is...
#  58949  marc sneyd is an english professional rugby le...
#  58950  john hartley ward arigo born december 10 1978 ...
#  58954  paul eugene foytack born november 16 1930 in s...
#  58960  sergey erzrumyan born on 22 november 1980 is a...
#  58962  david leslie born 14 april 1952 is a former sc...
#  58968  kurt luby born 6 march 1963 in bolton lancashi...
#  58969  raymond joseph robert daviault born may 27 193...
#  58982  jeffrey edward gray born april 10 1963 in rich...
#  58985  craig davis born 2 october 1954 in ross tasman...
#  58987  michael edwin bruhert born june 21 1951 is a f...
#  58988  donald jacob jake hager born march 24 1982 is ...
#  58992  jim eddy is a football coach who worked in the...
#  58993  edgar enrique rentera herazo spanish pronuncia...
#  59003  beth dunkenberger is in her second season with...
#  59007  brad huse born june 27 1966 is an american col...
#  59010  kaid yusef mohamed born 23 july 1984 is a wels...
#  59018  jim casey born august 2 1957 in glasgow is a r...
#  59026  richard john thompson born 11 april 1969 in ha...
#  59028  eric andrew naposki born december 20 1966 is a...
#  59051  geoffrey kipsang kamworor born 22 november 199...
#  59052  david wayne nilsson born 14 december 1969 is a...
#  59065  decovan kadell dee brown born november 29 1968...
#  59068  david william royce cass born 27 march 1962 in...
#  59069  keith hector elias born february 3 1972 in lac...
#
#  [11510 rows x 3 columns],
#  'matrix': <11510x547979 sparse matrix of type '<type 'numpy.float64'>'
#  	with 1885831 stored elements in Compressed Sparse Row format>}

# %% [markdown]
# And here is the content of the other cluster we named `right_child`.

# %%
right_child
# Out:
# {'centroid': array([  3.00882137e-06,   0.00000000e+00,   2.88868244e-06, ...,
#           1.10291526e-04,   9.00609890e-05,   2.03703564e-05]),
#  'dataframe':                                                      URI  \
#  1           <http://dbpedia.org/resource/Alfred_J._Lewy>
#  2            <http://dbpedia.org/resource/Harpdog_Brown>
#  3      <http://dbpedia.org/resource/Franz_Rottensteiner>
#  4                   <http://dbpedia.org/resource/G-Enka>
#  5            <http://dbpedia.org/resource/Sam_Henderson>
#  6            <http://dbpedia.org/resource/Aaron_LaCrate>
#  7          <http://dbpedia.org/resource/Trevor_Ferguson>
#  8             <http://dbpedia.org/resource/Grant_Nelson>
#  9             <http://dbpedia.org/resource/Cathy_Caruth>
#  10            <http://dbpedia.org/resource/Sophie_Crumb>
#  11           <http://dbpedia.org/resource/Jenn_Ashworth>
#  12        <http://dbpedia.org/resource/Jonathan_Hoefler>
#  13     <http://dbpedia.org/resource/Anthony_Gueterboc...
#  14      <http://dbpedia.org/resource/David_Chernushenko>
#  15          <http://dbpedia.org/resource/Joerg_Steineck>
#  16          <http://dbpedia.org/resource/Andrew_Pinsent>
#  18       <http://dbpedia.org/resource/Alexandros_Mouzas>
#  19     <http://dbpedia.org/resource/John_Angus_Campbell>
#  20          <http://dbpedia.org/resource/Chris_Batstone>
#  23           <http://dbpedia.org/resource/Faith_Soloway>
#  24            <http://dbpedia.org/resource/Tom_Jennings>
#  26         <http://dbpedia.org/resource/Anthony_Caruana>
#  27     <http://dbpedia.org/resource/Ian_Mitchell_(aut...
#  29            <http://dbpedia.org/resource/Emily_Osment>
#  31     <http://dbpedia.org/resource/Ted_Hill_(mathema...
#  32         <http://dbpedia.org/resource/Mindaugas_Murza>
#  34          <http://dbpedia.org/resource/Douglas_Davies>
#  35     <http://dbpedia.org/resource/Freimut_B%C3%B6rn...
#  36     <http://dbpedia.org/resource/Th%C3%BCring_Br%C...
#  37         <http://dbpedia.org/resource/Aharon_Solomons>
#  ...                                                  ...
#  59036        <http://dbpedia.org/resource/Sabitri_Mitra>
#  59037     <http://dbpedia.org/resource/Roni_Lynn_Deutch>
#  59038           <http://dbpedia.org/resource/Simon_Vega>
#  59039          <http://dbpedia.org/resource/Cho_Oh-hyun>
#  59040  <http://dbpedia.org/resource/Gail_Kulick_Jackson>
#  59041          <http://dbpedia.org/resource/Mokob%C3%A9>
#  59042      <http://dbpedia.org/resource/F._Enzio_Busche>
#  59043      <http://dbpedia.org/resource/Christian_Wiman>
#  59044  <http://dbpedia.org/resource/Ellyn_Setnor_Bogd...
#  59045          <http://dbpedia.org/resource/Katya_Adler>
#  59046   <http://dbpedia.org/resource/Anthony-Noel_Kelly>
#  59047       <http://dbpedia.org/resource/Mignon_Clyburn>
#  59048    <http://dbpedia.org/resource/Charles_A._Miller>
#  59049       <http://dbpedia.org/resource/Rodolfo_Parada>
#  59050  <http://dbpedia.org/resource/Giwi_Margwelaschw...
#  59053       <http://dbpedia.org/resource/Jessica_Jordan>
#  59054     <http://dbpedia.org/resource/Marina_Mulyayeva>
#  59055  <http://dbpedia.org/resource/Jo%C3%ABl_de_Rosnay>
#  59056          <http://dbpedia.org/resource/Amy_Jenkins>
#  59057  <http://dbpedia.org/resource/Roy_Zimmerman_(sa...
#  59058        <http://dbpedia.org/resource/George_Krause>
#  59059           <http://dbpedia.org/resource/Sean_Slade>
#  59060         <http://dbpedia.org/resource/Lynne_Lipton>
#  59061             <http://dbpedia.org/resource/Rod_Wilt>
#  59062  <http://dbpedia.org/resource/Scott_Baker_(judge)>
#  59063  <http://dbpedia.org/resource/Dragoljub_Ojdani%...
#  59064            <http://dbpedia.org/resource/Oz_Bengur>
#  59066           <http://dbpedia.org/resource/Olari_Elts>
#  59067       <http://dbpedia.org/resource/Scott_F._Crago>
#  59070         <http://dbpedia.org/resource/Fawaz_Damrah>
#
#                                            name  \
#  1                               Alfred J. Lewy
#  2                                Harpdog Brown
#  3                          Franz Rottensteiner
#  4                                       G-Enka
#  5                                Sam Henderson
#  6                                Aaron LaCrate
#  7                              Trevor Ferguson
#  8                                 Grant Nelson
#  9                                 Cathy Caruth
#  10                                Sophie Crumb
#  11                               Jenn Ashworth
#  12                            Jonathan Hoefler
#  13     Anthony Gueterbock, 18th Baron Berkeley
#  14                          David Chernushenko
#  15                              Joerg Steineck
#  16                              Andrew Pinsent
#  18                           Alexandros Mouzas
#  19                         John Angus Campbell
#  20                              Chris Batstone
#  23                               Faith Soloway
#  24                                Tom Jennings
#  26                             Anthony Caruana
#  27                       Ian Mitchell (author)
#  29                                Emily Osment
#  31                    Ted Hill (mathematician)
#  32                             Mindaugas Murza
#  34                              Douglas Davies
#  35                        Freimut B%C3%B6rngen
#  36                      Th%C3%BCring Br%C3%A4m
#  37                             Aharon Solomons
#  ...                                        ...
#  59036                            Sabitri Mitra
#  59037                         Roni Lynn Deutch
#  59038                               Simon Vega
#  59039                              Cho Oh-hyun
#  59040                      Gail Kulick Jackson
#  59041                              Mokob%C3%A9
#  59042                          F. Enzio Busche
#  59043                          Christian Wiman
#  59044                   Ellyn Setnor Bogdanoff
#  59045                              Katya Adler
#  59046                       Anthony-Noel Kelly
#  59047                           Mignon Clyburn
#  59048                        Charles A. Miller
#  59049                           Rodolfo Parada
#  59050                     Giwi Margwelaschwili
#  59053                           Jessica Jordan
#  59054                         Marina Mulyayeva
#  59055                      Jo%C3%ABl de Rosnay
#  59056                              Amy Jenkins
#  59057                 Roy Zimmerman (satirist)
#  59058                            George Krause
#  59059                               Sean Slade
#  59060                             Lynne Lipton
#  59061                                 Rod Wilt
#  59062                      Scott Baker (judge)
#  59063                   Dragoljub Ojdani%C4%87
#  59064                                Oz Bengur
#  59066                               Olari Elts
#  59067                           Scott F. Crago
#  59070                             Fawaz Damrah
#
#                                                      text
#  1      alfred j lewy aka sandy lewy graduated from un...
#  2      harpdog brown is a singer and harmonica player...
#  3      franz rottensteiner born in waidmannsfeld lowe...
#  4      henry krvits born 30 december 1974 in tallinn ...
#  5      sam henderson born october 18 1969 is an ameri...
#  6      aaron lacrate is an american music producer re...
#  7      trevor ferguson aka john farrow born 11 novemb...
#  8      grant nelson born 27 april 1971 in london also...
#  9      cathy caruth born 1955 is frank h t rhodes pro...
#  10     sophia violet sophie crumb born september 27 1...
#  11     jenn ashworth is an english writer she was bor...
#  12     jonathan hoefler born august 22 1970 is an ame...
#  13     anthony fitzhardinge gueterbock 18th baron ber...
#  14     david chernushenko born june 1963 in calgary a...
#  15     joerg steineck is a german filmmaker editor an...
#  16     fr andrew pinsent born 19 august 1966 is resea...
#  18     alexandros mouzas born 1962 is a greek compose...
#  19     john angus campbell born march 10 1942 in port...
#  20     chris batstone was the 20002002 lead singer of...
#  23     faith soloway born march 28 1964 is an america...
#  24     tom jennings born 1955 as thomas daniel jennin...
#  26     anthony caruana born 2 january 1968 is a melbo...
#  27     ian mitchell is a scottish author who grew up ...
#  29     emily jordan osment born march 10 1992 is an a...
#  31     theodore preston hill born december 28 1943 is...
#  32     mindaugas gervaldas until 2012 year mindaugas ...
#  34     douglas james davies born 1947 is professor in...
#  35     freimut brngen born october 17 1930 is a germa...
#  36     thring brm born 10 april 1944 is a swiss compo...
#  37     aharon solomons b september 27 1939 is a freed...
#  ...                                                  ...
#  59036  sabitri mitra is an indian politician belongin...
#  59037  roni lynn deutch is a former tax attorney and ...
#  59038  simon h vega born october 8 1935 is a retired ...
#  59039  seorak musan cho oh hyun born in 1932 in mirya...
#  59040  gail kulick jackson born may 29 1959 is a minn...
#  59041  mokob traor better known by the mononym mokob ...
#  59042  friedrich enzio busche born 5 april 1930 dortm...
#  59043  christian wiman is an american poet and editor...
#  59044  ellyn setnor bogdanoff born october 17 1959 wa...
#  59045  katya adler born 1972 is a british journalist ...
#  59046  anthonynoel kelly born 1956 is a british artis...
#  59047  mignon l clyburn born march 22 1962 is a commi...
#  59048  charles a miller born october 27 1937 in washi...
#  59049  rodolfo parada lillo is a chilean musician com...
#  59050  giwi margwelaschwili georgian born december 14...
#  59053  jessica anne jordan burton born 6 may 1984 in ...
#  59054  marina vladimirovna mulyayeva kazakh born apri...
#  59055  jol de rosnay born 1937 phd from the massachus...
#  59056  amy jenkins born 1966 in london is an english ...
#  59057  roy zimmerman born october 7 1957 is an americ...
#  59058  george krause born 1937 philadelphia pennsylva...
#  59059  sean slade b november 14 1957 lansing michigan...
#  59060  lynne lipton is an american film stage televis...
#  59061  rod wilt is a former republican member of the ...
#  59062  sir thomas scott gillespie baker born 10 decem...
#  59063  dragoljub ojdani serbian cyrillic born june 1 ...
#  59064  osman oz bengur born february 23 1949 is an am...
#  59066  olari elts born april 27 1971 in tallinn eston...
#  59067  scott francis crago born july 26 1963 twin bro...
#  59070  fawaz mohammed damrah arabic fawwz damra was t...
#
#  [47561 rows x 3 columns],
#  'matrix': <47561x547979 sparse matrix of type '<type 'numpy.float64'>'
#  	with 8493452 stored elements in Compressed Sparse Row format>}

# %% [markdown]
# ## Visualize the bipartition

# %% [markdown]
# We provide you with a modified version of the visualization function from the k-means assignment. For each cluster, we print the top 5 words with highest TF-IDF weights in the centroid and display excerpts for the 8 nearest neighbors of the centroid.

# %%
def display_single_tf_idf_cluster(cluster, map_index_to_word):
    '''map_index_to_word: SFrame specifying the mapping betweeen words and column indices'''
    
    wiki_subset   = cluster['dataframe']
    tf_idf_subset = cluster['matrix']
    centroid      = cluster['centroid']
    
    # Print top 5 words with largest TF-IDF weights in the cluster
    idx = centroid.argsort()[::-1]
    for i in xrange(5):
        print('{0:s}:{1:.3f}'.format(map_index_to_word.index[idx[i]], centroid[idx[i]])),
    print('')
    
    # Compute distances from the centroid to all data points in the cluster.
    distances = pairwise_distances(tf_idf_subset, [centroid], metric='euclidean').flatten()
    # compute nearest neighbors of the centroid within the cluster.
    nearest_neighbors = distances.argsort()
    # For 8 nearest neighbors, print the title as well as first 180 characters of text.
    # Wrap the text at 80-character mark.
    for i in xrange(8):
        text = ' '.join(wiki_subset.iloc[nearest_neighbors[i]]['text'].split(None, 25)[0:25])
        print('* {0:50s} {1:.5f}\n  {2:s}\n  {3:s}'.format(wiki_subset.iloc[nearest_neighbors[i]]['name'],
              distances[nearest_neighbors[i]], text[:90], text[90:180] if len(text) > 90 else ''))
    print('')

# %%
left_child['centroid']
# Out:
# array([  0.00000000e+00,   8.57526623e-06,   0.00000000e+00, ...,
#          1.38560691e-04,   6.46049863e-05,   2.26551103e-05])

# %%
left_child['centroid'].shape
# Out:
# (547979,)

# %%
tf_idf.shape
# Out:
# (59071, 547979)

# %%
sum(left_child['centroid'])
# Out:
# 8.6960888147290429

# %% [markdown]
# Let's visualize the two child clusters:

# %%
display_single_tf_idf_cluster(left_child, map_index_to_word)
# Out:
# zvuku:0.040 zwerge:0.036 zwines:0.029 zumars:0.029 zx10rborn:0.028
# * Todd Williams                                      0.95468
#   todd michael williams born february 13 1971 in syracuse new york is a former major league
#   baseball relief pitcher he attended east syracuseminoa high school
# * Gord Sherven                                       0.95622
#   gordon r sherven born august 21 1963 in gravelbourg saskatchewan and raised in mankota sas
#   katchewan is a retired canadian professional ice hockey forward who played
# * Justin Knoedler                                    0.95639
#   justin joseph knoedler born july 17 1980 in springfield illinois is a former major league
#   baseball catcherknoedler was originally drafted by the st louis cardinals
# * Chris Day                                          0.95648
#   christopher nicholas chris day born 28 july 1975 is an english professional footballer who
#    plays as a goalkeeper for stevenageday started his career at tottenham
# * Tony Smith (footballer, born 1957)                 0.95653
#   anthony tony smith born 20 february 1957 is a former footballer who played as a central de
#   fender in the football league in the 1970s and
# * Ashley Prescott                                    0.95761
#   ashley prescott born 11 september 1972 is a former australian rules footballer he played w
#   ith the richmond and fremantle football clubs in the afl between
# * Leslie Lea                                         0.95802
#   leslie lea born 5 october 1942 in manchester is an english former professional footballer
#   he played as a midfielderlea began his professional career with blackpool
# * Tommy Anderson (footballer)                        0.95818
#   thomas cowan tommy anderson born 24 september 1934 in haddington is a scottish former prof
#   essional footballer he played as a forward and was noted for

# %%
display_single_tf_idf_cluster(right_child, map_index_to_word)
# Out:
# zwolsman:0.025 zx10r:0.017 zwigoff:0.012 zyuganovs:0.011 zyntherius:0.011
# * Anita Kunz                                         0.97401
#   anita e kunz oc born 1956 is a canadianborn artist and illustratorkunz has lived in london
#    new york and toronto contributing to magazines and working
# * Janet Jackson                                      0.97472
#   janet damita jo jackson born may 16 1966 is an american singer songwriter and actress know
#   n for a series of sonically innovative socially conscious and
# * Madonna (entertainer)                              0.97475
#   madonna louise ciccone tkoni born august 16 1958 is an american singer songwriter actress
#   and businesswoman she achieved popularity by pushing the boundaries of lyrical
# * %C3%81ine Hyland                                   0.97536
#   ine hyland ne donlon is emeritus professor of education and former vicepresident of univer
#   sity college cork ireland she was born in 1942 in athboy co
# * Jane Fonda                                         0.97621
#   jane fonda born lady jayne seymour fonda december 21 1937 is an american actress writer po
#   litical activist former fashion model and fitness guru she is
# * Christine Robertson                                0.97643
#   christine mary robertson born 5 october 1948 is an australian politician and former austra
#   lian labor party member of the new south wales legislative council serving
# * Pat Studdy-Clift                                   0.97643
#   pat studdyclift is an australian author specialising in historical fiction and nonfictionb
#   orn in 1925 she lived in gunnedah until she was sent to a boarding
# * Alexandra Potter                                   0.97646
#   alexandra potter born 1970 is a british author of romantic comediesborn in bradford yorksh
#   ire england and educated at liverpool university gaining an honors degree in

# %% [markdown]
# The left cluster consists of athletes, whereas the right cluster consists of non-athletes. So far, we have a single-level hierarchy consisting of two clusters, as follows:

# %% [markdown]
# ```
#                                            Wikipedia
#                                                +
#                                                |
#                     +--------------------------+--------------------+
#                     |                                               |
#                     +                                               +
#                  Athletes                                      Non-athletes
# ```

# %% [markdown]
# Is this hierarchy good enough? **When building a hierarchy of clusters, we must keep our particular application in mind.** For instance, we might want to build a **directory** for Wikipedia articles. A good directory would let you quickly narrow down your search to a small set of related articles. The categories of athletes and non-athletes are too general to facilitate efficient search. For this reason, we decide to build another level into our hierarchy of clusters with the goal of getting more specific cluster structure at the lower level. To that end, we subdivide both the `athletes` and `non-athletes` clusters.

# %% [markdown]
# ## Perform recursive bipartitioning

# %% [markdown]
# ### Cluster of athletes

# %% [markdown]
# To help identify the clusters we've built so far, let's give them easy-to-read aliases:

# %%
athletes = left_child
non_athletes = right_child

# %% [markdown]
# Using the bipartition function, we produce two child clusters of the athlete cluster:

# %%
# Bipartition the cluster of athletes
left_child_athletes, right_child_athletes = bipartition(athletes, maxiter=100, num_runs=6, seed=1)
# Out:
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Iteration  0, inertia 22100.232
# Iteration  0, inertia 22241.279
# Iteration  0, inertia 21717.211
# Iteration  0, inertia 21964.990
# Iteration  1, inertia 11163.410
# Iteration  1, inertia 11144.817
# Iteration  1, inertia 11119.067
# Iteration  1, inertia 11160.597
# Iteration  2, inertia 11134.998
# Iteration  2, inertia 11144.691
# Iteration  2, inertia 11105.094
# Iteration  2, inertia 11143.919
# Iteration  3, inertia 11125.568
# Iteration  3, inertia 11134.000
# Iteration  3, inertia 11103.271
# Iteration  3, inertia 11138.340
# Iteration  4, inertia 11120.867
# Iteration  4, inertia 11133.814
# Iteration  4, inertia 11103.108
# Iteration  4, inertia 11135.742
# Iteration  5, inertia 11120.533
# Iteration  5, inertia 11133.765
# Iteration  5, inertia 11103.103
# Converged at iteration 5: center shift 0.000000e+00 within tolerance 1.773880e-10
# Iteration  5, inertia 11135.108
# Initialization complete
# Iteration  6, inertia 11133.751
# Iteration  6, inertia 11120.150
# Iteration  6, inertia 11134.673
# Iteration  0, inertia 22055.192
# Iteration  7, inertia 11133.746
# Iteration  7, inertia 11119.283
# Iteration  7, inertia 11134.397
# Iteration  1, inertia 11125.968
# Iteration  8, inertia 11116.011
# Iteration  8, inertia 11133.744
# Converged at iteration 8: center shift 0.000000e+00 within tolerance 1.773880e-10
# Initialization complete
# Iteration  8, inertia 11134.295
# Iteration  2, inertia 11118.046
# Iteration  9, inertia 11108.227
# Iteration  0, inertia 22099.093
# Iteration  9, inertia 11134.255
# Iteration  3, inertia 11115.116
# Iteration 10, inertia 11103.960
# Iteration  1, inertia 11129.463
# Iteration 10, inertia 11134.238
# Iteration  4, inertia 11108.864
# Iteration 11, inertia 11103.532
# Iteration  2, inertia 11110.491
# Iteration 11, inertia 11134.226
# Iteration  5, inertia 11108.393
# Iteration  3, inertia 11108.751
# Iteration 12, inertia 11103.303
# Iteration 12, inertia 11134.212
# Iteration  6, inertia 11107.989
# Iteration  4, inertia 11108.680
# Iteration 13, inertia 11103.121
# Iteration 13, inertia 11134.199
# Iteration  7, inertia 11107.649
# Iteration  5, inertia 11108.669
# Iteration 14, inertia 11103.107
# Iteration 14, inertia 11134.187
# Iteration  8, inertia 11106.935
# Iteration  6, inertia 11108.666
# Iteration 15, inertia 11103.106
# Converged at iteration 15: center shift 0.000000e+00 within tolerance 1.773880e-10
# Iteration 15, inertia 11134.170
# Iteration  9, inertia 11105.395
# Iteration  7, inertia 11108.664
# Iteration 16, inertia 11134.111
# Iteration 10, inertia 11103.599
# Iteration 17, inertia 11134.008
# Iteration  8, inertia 11108.663
# Converged at iteration 8: center shift 0.000000e+00 within tolerance 1.773880e-10
# Iteration 11, inertia 11103.154
# Iteration 18, inertia 11133.915
# Iteration 12, inertia 11103.110
# Iteration 19, inertia 11133.855
# Iteration 13, inertia 11103.106
# Converged at iteration 13: center shift 0.000000e+00 within tolerance 1.773880e-10
# Iteration 20, inertia 11133.806
# Iteration 21, inertia 11133.769
# Iteration 22, inertia 11133.754
# Iteration 23, inertia 11133.752
# Iteration 24, inertia 11133.749
# Iteration 25, inertia 11133.748
# Converged at iteration 25: center shift 0.000000e+00 within tolerance 1.773880e-10

# %% [markdown]
# The left child cluster mainly consists of baseball players:

# %%
display_single_tf_idf_cluster(left_child_athletes, map_index_to_word)
# Out:
# zvuku:0.054 zwerge:0.043 zumars:0.038 zx10rborn:0.035 zuidams:0.030
# * Tony Smith (footballer, born 1957)                 0.94677
#   anthony tony smith born 20 february 1957 is a former footballer who played as a central de
#   fender in the football league in the 1970s and
# * Justin Knoedler                                    0.94746
#   justin joseph knoedler born july 17 1980 in springfield illinois is a former major league
#   baseball catcherknoedler was originally drafted by the st louis cardinals
# * Chris Day                                          0.94849
#   christopher nicholas chris day born 28 july 1975 is an english professional footballer who
#    plays as a goalkeeper for stevenageday started his career at tottenham
# * Todd Williams                                      0.94882
#   todd michael williams born february 13 1971 in syracuse new york is a former major league
#   baseball relief pitcher he attended east syracuseminoa high school
# * Todd Curley                                        0.95007
#   todd curley born 14 january 1973 is a former australian rules footballer who played for co
#   llingwood and the western bulldogs in the australian football league
# * Ashley Prescott                                    0.95015
#   ashley prescott born 11 september 1972 is a former australian rules footballer he played w
#   ith the richmond and fremantle football clubs in the afl between
# * Tommy Anderson (footballer)                        0.95037
#   thomas cowan tommy anderson born 24 september 1934 in haddington is a scottish former prof
#   essional footballer he played as a forward and was noted for
# * Leslie Lea                                         0.95065
#   leslie lea born 5 october 1942 in manchester is an english former professional footballer
#   he played as a midfielderlea began his professional career with blackpool

# %% [markdown]
# On the other hand, the right child cluster is a mix of players in association football, Austrailian rules football and ice hockey:

# %%
display_single_tf_idf_cluster(right_child_athletes, map_index_to_word)
# Out:
# zowie:0.045 zuberi:0.043 zululand:0.035 zyiit:0.031 zygouli:0.031
# * Alessandra Aguilar                                 0.93880
#   alessandra aguilar born 1 july 1978 in lugo is a spanish longdistance runner who specialis
#   es in marathon running she represented her country in the event
# * Heather Samuel                                     0.93999
#   heather barbara samuel born 6 july 1970 is a retired sprinter from antigua and barbuda who
#    specialized in the 100 and 200 metres in 1990
# * Viola Kibiwot                                      0.94037
#   viola jelagat kibiwot born december 22 1983 in keiyo district is a runner from kenya who s
#   pecialises in the 1500 metres kibiwot won her first
# * Ayelech Worku                                      0.94052
#   ayelech worku born june 12 1979 is an ethiopian longdistance runner most known for winning
#    two world championships bronze medals on the 5000 metres she
# * Krisztina Papp                                     0.94105
#   krisztina papp born 17 december 1982 in eger is a hungarian long distance runner she is th
#   e national indoor record holder over 5000 mpapp began
# * Petra Lammert                                      0.94230
#   petra lammert born 3 march 1984 in freudenstadt badenwrttemberg is a former german shot pu
#   tter and current bobsledder she was the 2009 european indoor champion
# * Morhad Amdouni                                     0.94231
#   morhad amdouni born 21 january 1988 in portovecchio is a french middle and longdistance ru
#   nner he was european junior champion in track and cross country
# * Brian Davis (golfer)                               0.94378
#   brian lester davis born 2 august 1974 is an english professional golferdavis was born in l
#   ondon he turned professional in 1994 and became a member

# %% [markdown]
# Our hierarchy of clusters now looks like this:
# ```
#                                            Wikipedia
#                                                +
#                                                |
#                     +--------------------------+--------------------+
#                     |                                               |
#                     +                                               +
#                  Athletes                                      Non-athletes
#                     +
#                     |
#         +-----------+--------+
#         |                    |
#         |            association football/
#         +          Austrailian rules football/
#      baseball             ice hockey
# ```

# %% [markdown]
# Should we keep subdividing the clusters? If so, which cluster should we subdivide? To answer this question, we again think about our application. Since we organize our directory by topics, it would be nice to have topics that are about as coarse as each other. For instance, if one cluster is about baseball, we expect some other clusters about football, basketball, volleyball, and so forth. That is, **we would like to achieve similar level of granularity for all clusters.**
#
# Notice that the right child cluster is more coarse than the left child cluster. The right cluster posseses a greater variety of topics than the left (ice hockey/association football/Austrialian football vs. baseball). So the right child cluster should be subdivided further to produce finer child clusters.

# %% [markdown]
# Let's give the clusters aliases as well:

# %%
baseball            = left_child_athletes
ice_hockey_football = right_child_athletes

# %% [markdown]
# ### Cluster of ice hockey players and football players

# %% [markdown]
# In answering the following quiz question, take a look at the topics represented in the top documents (those closest to the centroid), as well as the list of words with highest TF-IDF weights.
#
# Let us bipartition the cluster of ice hockey and football players.

# %%
left_child_ihs, right_child_ihs = bipartition(ice_hockey_football, maxiter=100, num_runs=6, seed=1)
# Out:
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Iteration  0, inertia 5545.820
# Iteration  0, inertia 5669.348
# Iteration  0, inertia 5690.017
# Iteration  0, inertia 5677.596
# Iteration  1, inertia 2864.434
# Iteration  1, inertia 2840.933
# Iteration  1, inertia 2857.828
# Iteration  1, inertia 2868.816
# Iteration  2, inertia 2842.140
# Iteration  2, inertia 2848.948
# Iteration  2, inertia 2837.362
# Iteration  2, inertia 2855.981
# Iteration  3, inertia 2839.179
# Iteration  3, inertia 2841.765
# Iteration  3, inertia 2852.776
# Iteration  3, inertia 2837.315
# Iteration  4, inertia 2838.790
# Iteration  4, inertia 2837.081
# Iteration  4, inertia 2852.441
# Iteration  4, inertia 2837.303
# Iteration  5, inertia 2837.344
# Iteration  5, inertia 2852.120
# Iteration  5, inertia 2837.054
# Iteration  5, inertia 2837.300
# Converged at iteration 5: center shift 0.000000e+00 within tolerance 1.754910e-10
# Initialization complete
# Iteration  6, inertia 2837.324
# Iteration  6, inertia 2851.712
# Iteration  6, inertia 2837.042
# Iteration  0, inertia 5565.511
# Iteration  7, inertia 2851.354
# Iteration  7, inertia 2837.316
# Iteration  7, inertia 2837.037
# Iteration  1, inertia 2841.352
# Iteration  8, inertia 2851.116
# Iteration  8, inertia 2837.313
# Iteration  2, inertia 2838.031
# Iteration  8, inertia 2837.036
# Converged at iteration 8: center shift 0.000000e+00 within tolerance 1.754910e-10
# Initialization complete
# Iteration  9, inertia 2851.039
# Iteration  9, inertia 2837.310
# Iteration  3, inertia 2837.519
# Iteration  0, inertia 5693.887
# Iteration 10, inertia 2851.023
# Iteration 10, inertia 2837.308
# Iteration  4, inertia 2837.362
# Iteration  1, inertia 2857.463
# Iteration 11, inertia 2851.003
# Iteration 11, inertia 2837.306
# Converged at iteration 11: center shift 0.000000e+00 within tolerance 1.754910e-10
# Iteration  5, inertia 2837.317
# Iteration  2, inertia 2851.924
# Iteration 12, inertia 2850.992
# Iteration  6, inertia 2837.311
# Iteration  3, inertia 2851.104
# Iteration  7, inertia 2837.306
# Iteration 13, inertia 2850.984
# Converged at iteration 13: center shift 0.000000e+00 within tolerance 1.754910e-10
# Iteration  4, inertia 2850.698
# Iteration  8, inertia 2837.304
# Iteration  5, inertia 2850.362
# Iteration  9, inertia 2837.302
# Converged at iteration 9: center shift 0.000000e+00 within tolerance 1.754910e-10
# Iteration  6, inertia 2849.992
# Iteration  7, inertia 2849.937
# Iteration  8, inertia 2849.920
# Iteration  9, inertia 2849.913
# Iteration 10, inertia 2849.911
# Iteration 11, inertia 2849.910
# Iteration 12, inertia 2849.906
# Converged at iteration 12: center shift 0.000000e+00 within tolerance 1.754910e-10

# %%
display_single_tf_idf_cluster(left_child_ihs, map_index_to_word)
# Out:
# zowie:0.064 zyiit:0.039 zwolsman:0.038 zealandamerican:0.038 zolecki:0.037
# * Heather Samuel                                     0.91590
#   heather barbara samuel born 6 july 1970 is a retired sprinter from antigua and barbuda who
#    specialized in the 100 and 200 metres in 1990
# * Krisztina Papp                                     0.91672
#   krisztina papp born 17 december 1982 in eger is a hungarian long distance runner she is th
#   e national indoor record holder over 5000 mpapp began
# * Ayelech Worku                                      0.91892
#   ayelech worku born june 12 1979 is an ethiopian longdistance runner most known for winning
#    two world championships bronze medals on the 5000 metres she
# * Viola Kibiwot                                      0.91906
#   viola jelagat kibiwot born december 22 1983 in keiyo district is a runner from kenya who s
#   pecialises in the 1500 metres kibiwot won her first
# * Alessandra Aguilar                                 0.91955
#   alessandra aguilar born 1 july 1978 in lugo is a spanish longdistance runner who specialis
#   es in marathon running she represented her country in the event
# * Antonina Yefremova                                 0.92054
#   antonina yefremova born 19 july 1981 is a ukrainian sprinter who specializes in the 400 me
#   tres yefremova received a twoyear ban in 2012 for using
# * Marian Burnett                                     0.92251
#   marian joan burnett born 22 february 1976 in linden is a female middledistance runner from
#    guyana who specialises in the 800 metres she competed in
# * Wang Xiuting                                       0.92377
#   wang xiuting chinese born 11 may 1965 in shandong is a chinese former longdistance runners
#   he rose to prominence with a victory in the 10000 metres

# %%
display_single_tf_idf_cluster(right_child_ihs, map_index_to_word)
# Out:
# zuberi:0.118 zadnji:0.089 zimmermann:0.062 zekiye:0.060 zululand:0.054
# * Bob Heintz                                         0.88057
#   robert edward heintz born may 1 1970 is an american professional golfer who plays on the n
#   ationwide tourheintz was born in syosset new york he
# * Tim Conley                                         0.88274
#   tim conley born december 8 1958 is an american professional golfer who played on the pga t
#   our nationwide tour and most recently the champions tourconley
# * Bruce Zabriski                                     0.88279
#   bruce zabriski born august 3 1957 is an american professional golfer who played on the pga
#    tour european tour and the nationwide tourzabriski joined the
# * Sonny Skinner                                      0.88438
#   sonny skinner born august 18 1960 is an american professional golfer who plays on the cham
#   pions tourskinner was born in portsmouth virginia he turned professional
# * Brian Davis (golfer)                               0.88482
#   brian lester davis born 2 august 1974 is an english professional golferdavis was born in l
#   ondon he turned professional in 1994 and became a member
# * Greg Chalmers                                      0.88501
#   greg j chalmers born 11 october 1973 is an australian professional golfer who has played o
#   n both the european tour and the pga tourchalmers was
# * Todd Barranger                                     0.88552
#   todd barranger born october 19 1968 is an american professional golfer who played on the p
#   ga tour asian tour and the nationwide tourbarranger joined the
# * Dick Mast                                          0.88830
#   richard mast born march 23 1951 is an american professional golfer who has played on the p
#   ga tour nationwide tour and champions tourmast was born

# %% [markdown]
# **Quiz Question**. Which diagram best describes the hierarchy right after splitting the `ice_hockey_football` cluster? Refer to the quiz form for the diagrams.

# %% [markdown]
# **Caution**. The granularity criteria is an imperfect heuristic and must be taken with a grain of salt. It takes a lot of manual intervention to obtain a good hierarchy of clusters.
#
# * **If a cluster is highly mixed, the top articles and words may not convey the full picture of the cluster.** Thus, we may be misled if we judge the purity of clusters solely by their top documents and words.
# * **Many interesting topics are hidden somewhere inside the clusters but do not appear in the visualization.** We may need to subdivide further to discover new topics. For instance, subdividing the `ice_hockey_football` cluster led to the appearance of runners and golfers.

# %% [markdown]
# ### Cluster of non-athletes

# %% [markdown]
# Now let us subdivide the cluster of non-athletes.

# %%
# Bipartition the cluster of non-athletes
left_child_non_athletes, right_child_non_athletes = bipartition(non_athletes, maxiter=100, num_runs=6, seed=1)
# Out:
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Iteration  0, inertia 93346.712
# Iteration  0, inertia 93161.798
# Iteration  0, inertia 93170.164
# Iteration  0, inertia 93261.291
# Iteration  1, inertia 46885.838
# Iteration  1, inertia 46884.698
# Iteration  1, inertia 46929.611
# Iteration  1, inertia 46896.417
# Iteration  2, inertia 46848.998
# Iteration  2, inertia 46847.112
# Iteration  2, inertia 46864.557
# Iteration  2, inertia 46852.047
# Iteration  3, inertia 46846.011
# Iteration  3, inertia 46845.375
# Iteration  3, inertia 46856.212
# Iteration  3, inertia 46846.735
# Iteration  4, inertia 46845.130
# Iteration  4, inertia 46845.156
# Iteration  4, inertia 46853.087
# Iteration  4, inertia 46845.435
# Iteration  5, inertia 46844.878
# Iteration  5, inertia 46845.081
# Iteration  5, inertia 46851.404
# Iteration  5, inertia 46845.126
# Iteration  6, inertia 46844.801
# Iteration  6, inertia 46845.038
# Iteration  6, inertia 46850.774
# Iteration  6, inertia 46845.041
# Iteration  7, inertia 46844.772
# Iteration  7, inertia 46845.003
# Iteration  7, inertia 46850.202
# Iteration  7, inertia 46844.999
# Iteration  8, inertia 46844.761
# Iteration  8, inertia 46844.968
# Iteration  8, inertia 46849.560
# Iteration  8, inertia 46844.963
# Iteration  9, inertia 46844.755
# Iteration  9, inertia 46844.935
# Iteration  9, inertia 46848.833
# Iteration  9, inertia 46844.931
# Iteration 10, inertia 46844.753
# Iteration 10, inertia 46848.037
# Iteration 10, inertia 46844.906
# Iteration 10, inertia 46844.902
# Iteration 11, inertia 46844.752
# Iteration 11, inertia 46847.351
# Iteration 11, inertia 46844.879
# Iteration 11, inertia 46844.877
# Iteration 12, inertia 46844.751
# Iteration 12, inertia 46846.879
# Iteration 12, inertia 46844.858
# Iteration 12, inertia 46844.855
# Iteration 13, inertia 46844.749
# Iteration 13, inertia 46846.575
# Iteration 13, inertia 46844.838
# Iteration 13, inertia 46844.834
# Iteration 14, inertia 46844.749
# Iteration 14, inertia 46846.361
# Iteration 14, inertia 46844.820
# Iteration 14, inertia 46844.818
# Iteration 15, inertia 46844.748
# Iteration 15, inertia 46846.220
# Iteration 15, inertia 46844.807
# Iteration 15, inertia 46844.806
# Iteration 16, inertia 46844.748
# Iteration 16, inertia 46846.107
# Iteration 16, inertia 46844.795
# Iteration 16, inertia 46844.794
# Iteration 17, inertia 46844.748
# Iteration 17, inertia 46846.023
# Iteration 17, inertia 46844.786
# Iteration 17, inertia 46844.786
# Iteration 18, inertia 46844.747
# Converged at iteration 18: center shift 0.000000e+00 within tolerance 1.803028e-10
# Initialization complete
# Iteration 18, inertia 46845.954
# Iteration 18, inertia 46844.779
# Iteration 18, inertia 46844.778
# Iteration  0, inertia 93232.430
# Iteration 19, inertia 46845.902
# Iteration 19, inertia 46844.774
# Iteration 19, inertia 46844.772
# Iteration  1, inertia 46901.484
# Iteration 20, inertia 46845.870
# Iteration 20, inertia 46844.769
# Iteration 20, inertia 46844.768
# Iteration  2, inertia 46855.525
# Iteration 21, inertia 46845.848
# Iteration 21, inertia 46844.766
# Iteration 21, inertia 46844.765
# Iteration  3, inertia 46848.942
# Iteration 22, inertia 46845.826
# Iteration 22, inertia 46844.764
# Iteration 22, inertia 46844.763
# Iteration  4, inertia 46846.313
# Iteration 23, inertia 46845.806
# Iteration 23, inertia 46844.762
# Iteration 23, inertia 46844.762
# Iteration  5, inertia 46845.854
# Iteration 24, inertia 46845.789
# Iteration 24, inertia 46844.761
# Iteration 24, inertia 46844.761
# Iteration 25, inertia 46845.776
# Iteration  6, inertia 46845.771
# Iteration 25, inertia 46844.761
# Iteration 25, inertia 46844.761
# Converged at iteration 25: center shift 0.000000e+00 within tolerance 1.803028e-10
# Initialization complete
# Iteration 26, inertia 46845.764
# Iteration  7, inertia 46845.741
# Iteration 26, inertia 46844.761
# Converged at iteration 26: center shift 0.000000e+00 within tolerance 1.803028e-10
# Iteration  0, inertia 93280.331
# Iteration 27, inertia 46845.758
# Iteration  8, inertia 46845.729
# Iteration  1, inertia 46883.295
# Iteration 28, inertia 46845.754
# Iteration  9, inertia 46845.722
# Iteration  2, inertia 46851.295
# Iteration 29, inertia 46845.749
# Iteration 10, inertia 46845.719
# Iteration  3, inertia 46847.299
# Iteration 11, inertia 46845.718
# Iteration 30, inertia 46845.745
# Iteration  4, inertia 46846.312
# Iteration 31, inertia 46845.742
# Iteration 12, inertia 46845.718
# Iteration  5, inertia 46846.031
# Iteration 32, inertia 46845.740
# Iteration 13, inertia 46845.717
# Iteration  6, inertia 46845.906
# Iteration 33, inertia 46845.738
# Iteration 14, inertia 46845.717
# Iteration  7, inertia 46845.851
# Iteration 34, inertia 46845.735
# Iteration 15, inertia 46845.716
# Iteration  8, inertia 46845.818
# Iteration 35, inertia 46845.733
# Iteration 16, inertia 46845.716
# Iteration  9, inertia 46845.788
# Iteration 36, inertia 46845.732
# Iteration 17, inertia 46845.715
# Iteration 10, inertia 46845.769
# Iteration 37, inertia 46845.731
# Iteration 18, inertia 46845.715
# Iteration 11, inertia 46845.758
# Iteration 38, inertia 46845.731
# Iteration 19, inertia 46845.715
# Iteration 12, inertia 46845.751
# Iteration 39, inertia 46845.731
# Converged at iteration 39: center shift 0.000000e+00 within tolerance 1.803028e-10
# Iteration 20, inertia 46845.715
# Converged at iteration 20: center shift 0.000000e+00 within tolerance 1.803028e-10
# Iteration 13, inertia 46845.746
# Iteration 14, inertia 46845.742
# Iteration 15, inertia 46845.740
# Iteration 16, inertia 46845.738
# Iteration 17, inertia 46845.736
# Iteration 18, inertia 46845.733
# Iteration 19, inertia 46845.731
# Iteration 20, inertia 46845.731
# Iteration 21, inertia 46845.730
# Iteration 22, inertia 46845.730
# Converged at iteration 22: center shift 0.000000e+00 within tolerance 1.803028e-10

# %%
display_single_tf_idf_cluster(left_child_non_athletes, map_index_to_word)
# Out:
# zyntherius:0.016 zyuganovs:0.013 zwolsman:0.013 zupan:0.012 zx81:0.012
# * Barry Sullivan (lawyer)                            0.97227
#   barry sullivan is a chicago lawyer and as of july 1 2009 the cooney conway chair in advoca
#   cy at loyola university chicago school of law
# * Kayee Griffin                                      0.97444
#   kayee frances griffin born 6 february 1950 is an australian politician and former australi
#   an labor party member of the new south wales legislative council serving
# * Christine Robertson                                0.97450
#   christine mary robertson born 5 october 1948 is an australian politician and former austra
#   lian labor party member of the new south wales legislative council serving
# * James A. Joseph                                    0.97464
#   james a joseph born 1935 is an american former diplomatjoseph is professor of the practice
#    of public policy studies at duke university and founder of
# * David Anderson (British Columbia politician)       0.97492
#   david a anderson pc oc born august 16 1937 in victoria british columbia is a former canadi
#   an cabinet minister educated at victoria college in victoria
# * Mary Ellen Coster Williams                         0.97594
#   mary ellen coster williams born april 3 1953 is a judge of the united states court of fede
#   ral claims appointed to that court in 2003
# * Sven Erik Holmes                                   0.97600
#   sven erik holmes is a former federal judge and currently the vice chairman legal risk and
#   regulatory and chief legal officer for kpmg llp a
# * Andrew Fois                                        0.97652
#   andrew fois is an attorney living and working in washington dc as of april 9 2012 he will
#   be serving as the deputy attorney general

# %%
display_single_tf_idf_cluster(right_child_non_athletes, map_index_to_word)
# Out:
# zwolsman:0.039 zx10r:0.030 zwigoff:0.023 zwacksalles:0.021 zupanprofessor:0.015
# * Madonna (entertainer)                              0.96092
#   madonna louise ciccone tkoni born august 16 1958 is an american singer songwriter actress
#   and businesswoman she achieved popularity by pushing the boundaries of lyrical
# * Janet Jackson                                      0.96153
#   janet damita jo jackson born may 16 1966 is an american singer songwriter and actress know
#   n for a series of sonically innovative socially conscious and
# * Cher                                               0.96540
#   cher r born cherilyn sarkisian may 20 1946 is an american singer actress and television ho
#   st described as embodying female autonomy in a maledominated industry
# * Laura Smith                                        0.96600
#   laura smith is a canadian folk singersongwriter she is best known for her 1995 single shad
#   e of your love one of the years biggest hits
# * Natashia Williams                                  0.96677
#   natashia williamsblach born august 2 1978 is an american actress and former wonderbra camp
#   aign model who is perhaps best known for her role as shane
# * Anita Kunz                                         0.96716
#   anita e kunz oc born 1956 is a canadianborn artist and illustratorkunz has lived in london
#    new york and toronto contributing to magazines and working
# * Maggie Smith                                       0.96747
#   dame margaret natalie maggie smith ch dbe born 28 december 1934 is an english actress she
#   made her stage debut in 1952 and has had
# * Lizzie West                                        0.96752
#   lizzie west born in brooklyn ny on july 21 1973 is a singersongwriter her music can be des
#   cribed as a blend of many genres including

# %% [markdown]
# Neither of the clusters show clear topics, apart from the genders. Let us divide them further.

# %%
male_non_athletes = left_child_non_athletes
female_non_athletes = right_child_non_athletes

# %%
# Bipartition the cluster of non-athletes
left_child_male_non_athletes, right_child_male_non_athletes = bipartition(male_non_athletes, maxiter=100, num_runs=6, seed=1)
# Out:
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Iteration  0, inertia 48531.918
# Iteration  0, inertia 48311.627
# Iteration  0, inertia 48273.633
# Iteration  0, inertia 48365.413
# Iteration  1, inertia 24317.797
# Iteration  1, inertia 24319.179
# Iteration  1, inertia 24334.175
# Iteration  1, inertia 24306.421
# Iteration  2, inertia 24291.546
# Iteration  2, inertia 24310.127
# Iteration  2, inertia 24296.701
# Iteration  2, inertia 24298.458
# Iteration  3, inertia 24301.189
# Iteration  3, inertia 24286.515
# Iteration  3, inertia 24296.419
# Iteration  3, inertia 24295.281
# Iteration  4, inertia 24284.880
# Iteration  4, inertia 24297.907
# Iteration  4, inertia 24295.556
# Iteration  4, inertia 24294.428
# Iteration  5, inertia 24284.052
# Iteration  5, inertia 24294.829
# Iteration  5, inertia 24293.195
# Iteration  5, inertia 24295.978
# Iteration  6, inertia 24293.846
# Iteration  6, inertia 24294.186
# Iteration  6, inertia 24291.134
# Iteration  6, inertia 24283.474
# Iteration  7, inertia 24292.174
# Iteration  7, inertia 24288.909
# Iteration  7, inertia 24291.736
# Iteration  7, inertia 24282.838
# Iteration  8, inertia 24289.745
# Iteration  8, inertia 24287.309
# Iteration  8, inertia 24288.636
# Iteration  8, inertia 24282.591
# Iteration  9, inertia 24285.830
# Iteration  9, inertia 24287.902
# Iteration  9, inertia 24286.368
# Iteration  9, inertia 24282.477
# Iteration 10, inertia 24284.716
# Iteration 10, inertia 24286.411
# Iteration 10, inertia 24284.439
# Iteration 10, inertia 24282.407
# Iteration 11, inertia 24284.081
# Iteration 11, inertia 24285.154
# Iteration 11, inertia 24283.226
# Iteration 11, inertia 24282.365
# Iteration 12, inertia 24283.680
# Iteration 12, inertia 24282.703
# Iteration 12, inertia 24284.328
# Iteration 12, inertia 24282.337
# Iteration 13, inertia 24283.173
# Iteration 13, inertia 24282.485
# Iteration 13, inertia 24283.835
# Iteration 13, inertia 24282.316
# Iteration 14, inertia 24282.670
# Iteration 14, inertia 24282.394
# Iteration 14, inertia 24282.294
# Iteration 14, inertia 24283.395
# Iteration 15, inertia 24282.351
# Iteration 15, inertia 24282.491
# Iteration 15, inertia 24282.279
# Iteration 15, inertia 24282.786
# Iteration 16, inertia 24282.321
# Iteration 16, inertia 24282.399
# Iteration 16, inertia 24282.270
# Iteration 16, inertia 24282.541
# Iteration 17, inertia 24282.353
# Iteration 17, inertia 24282.299
# Iteration 17, inertia 24282.263
# Iteration 17, inertia 24282.429
# Iteration 18, inertia 24282.325
# Iteration 18, inertia 24282.281
# Iteration 18, inertia 24282.260
# Iteration 18, inertia 24282.367
# Iteration 19, inertia 24282.271
# Iteration 19, inertia 24282.302
# Iteration 19, inertia 24282.258
# Iteration 19, inertia 24282.338
# Iteration 20, inertia 24282.284
# Iteration 20, inertia 24282.264
# Iteration 20, inertia 24282.256
# Iteration 20, inertia 24282.313
# Iteration 21, inertia 24282.272
# Iteration 21, inertia 24282.261
# Iteration 21, inertia 24282.254
# Iteration 21, inertia 24282.292
# Iteration 22, inertia 24282.266
# Iteration 22, inertia 24282.258
# Iteration 22, inertia 24282.252
# Iteration 22, inertia 24282.275
# Iteration 23, inertia 24282.261
# Iteration 23, inertia 24282.256
# Iteration 23, inertia 24282.251
# Iteration 23, inertia 24282.267
# Iteration 24, inertia 24282.259
# Iteration 24, inertia 24282.254
# Iteration 24, inertia 24282.251
# Iteration 24, inertia 24282.262
# Iteration 25, inertia 24282.257
# Iteration 25, inertia 24282.252
# Iteration 25, inertia 24282.250
# Converged at iteration 25: center shift 0.000000e+00 within tolerance 1.800980e-10
# Iteration 25, inertia 24282.260
# Initialization complete
# Iteration 26, inertia 24282.255
# Iteration 26, inertia 24282.251
# Iteration  0, inertia 48699.209
# Iteration 26, inertia 24282.258
# Iteration 27, inertia 24282.253
# Iteration 27, inertia 24282.251
# Iteration  1, inertia 24310.689
# Iteration 27, inertia 24282.256
# Iteration 28, inertia 24282.252
# Iteration 28, inertia 24282.250
# Converged at iteration 28: center shift 0.000000e+00 within tolerance 1.800980e-10
# Initialization complete
# Iteration  2, inertia 24297.116
# Iteration 28, inertia 24282.254
# Iteration 29, inertia 24282.251
# Iteration  0, inertia 48119.088
# Iteration 29, inertia 24282.252
# Iteration  3, inertia 24296.213
# Iteration 30, inertia 24282.250
# Iteration  1, inertia 24307.373
# Iteration 30, inertia 24282.251
# Iteration  4, inertia 24295.867
# Iteration 31, inertia 24282.250
# Converged at iteration 31: center shift 0.000000e+00 within tolerance 1.800980e-10
# Iteration  2, inertia 24296.246
# Iteration 31, inertia 24282.251
# Iteration  5, inertia 24295.667
# Iteration  3, inertia 24295.000
# Iteration  6, inertia 24295.540
# Iteration 32, inertia 24282.250
# Converged at iteration 32: center shift 0.000000e+00 within tolerance 1.800980e-10
# Iteration  4, inertia 24293.991
# Iteration  7, inertia 24295.442
# Iteration  5, inertia 24292.540
# Iteration  8, inertia 24295.360
# Iteration  6, inertia 24290.865
# Iteration  9, inertia 24295.276
# Iteration  7, inertia 24289.610
# Iteration 10, inertia 24295.173
# Iteration  8, inertia 24288.601
# Iteration 11, inertia 24295.057
# Iteration  9, inertia 24287.281
# Iteration 12, inertia 24294.892
# Iteration 10, inertia 24285.539
# Iteration 13, inertia 24294.635
# Iteration 11, inertia 24284.417
# Iteration 14, inertia 24294.270
# Iteration 12, inertia 24283.889
# Iteration 15, inertia 24293.650
# Iteration 13, inertia 24283.461
# Iteration 16, inertia 24292.540
# Iteration 14, inertia 24282.849
# Iteration 17, inertia 24290.990
# Iteration 15, inertia 24282.574
# Iteration 18, inertia 24289.704
# Iteration 16, inertia 24282.456
# Iteration 19, inertia 24288.677
# Iteration 17, inertia 24282.385
# Iteration 20, inertia 24287.379
# Iteration 18, inertia 24282.349
# Iteration 21, inertia 24285.645
# Iteration 19, inertia 24282.325
# Iteration 22, inertia 24284.472
# Iteration 20, inertia 24282.304
# Iteration 23, inertia 24283.927
# Iteration 21, inertia 24282.286
# Iteration 24, inertia 24283.524
# Iteration 22, inertia 24282.273
# Iteration 25, inertia 24282.901
# Iteration 23, inertia 24282.265
# Iteration 26, inertia 24282.576
# Iteration 24, inertia 24282.261
# Iteration 27, inertia 24282.446
# Iteration 25, inertia 24282.259
# Iteration 28, inertia 24282.375
# Iteration 26, inertia 24282.257
# Iteration 29, inertia 24282.342
# Iteration 27, inertia 24282.255
# Iteration 30, inertia 24282.316
# Iteration 28, inertia 24282.253
# Iteration 31, inertia 24282.294
# Iteration 29, inertia 24282.252
# Iteration 32, inertia 24282.277
# Iteration 30, inertia 24282.251
# Iteration 33, inertia 24282.268
# Iteration 31, inertia 24282.250
# Iteration 34, inertia 24282.262
# Iteration 32, inertia 24282.250
# Converged at iteration 32: center shift 0.000000e+00 within tolerance 1.800980e-10
# Iteration 35, inertia 24282.260
# Iteration 36, inertia 24282.258
# Iteration 37, inertia 24282.256
# Iteration 38, inertia 24282.254
# Iteration 39, inertia 24282.252
# Iteration 40, inertia 24282.251
# Iteration 41, inertia 24282.251
# Iteration 42, inertia 24282.250
# Converged at iteration 42: center shift 0.000000e+00 within tolerance 1.800980e-10

# %%
display_single_tf_idf_cluster(left_child_male_non_athletes, map_index_to_word)
# Out:
# zurichminds:0.039 zumadespite:0.036 zuffelato:0.033 zwolsman:0.028 zuzana:0.026
# * Kayee Griffin                                      0.95170
#   kayee frances griffin born 6 february 1950 is an australian politician and former australi
#   an labor party member of the new south wales legislative council serving
# * Marcelle Mersereau                                 0.95417
#   marcelle mersereau born february 14 1942 in pointeverte new brunswick is a canadian politi
#   cian a civil servant for most of her career she also served
# * Lucienne Robillard                                 0.95453
#   lucienne robillard pc born june 16 1945 is a canadian politician and a member of the liber
#   al party of canada she sat in the house
# * Maureen Lyster                                     0.95590
#   maureen anne lyster born 10 september 1943 is an australian politician she was an australi
#   an labor party member of the victorian legislative assembly from 1985
# * Liz Cunningham                                     0.95690
#   elizabeth anne liz cunningham is an australian politician she was an independent member of
#    the legislative assembly of queensland from 1995 to 2015 representing the
# * Carol Skelton                                      0.95780
#   carol skelton pc born december 12 1945 in biggar saskatchewan is a canadian politician she
#    is a member of the security intelligence review committee which
# * Stephen Harper                                     0.95816
#   stephen joseph harper pc mp born april 30 1959 is a canadian politician who is the 22nd an
#   d current prime minister of canada and the
# * Doug Lewis                                         0.95875
#   douglas grinslade doug lewis pc qc born april 17 1938 is a former canadian politician a ch
#   artered accountant and lawyer by training lewis entered the

# %%
display_single_tf_idf_cluster(right_child_male_non_athletes, map_index_to_word)
# Out:
# zyntherius:0.018 zvezdy:0.015 zwane:0.013 zyuganovs:0.013 zwicky:0.010
# * Lawrence W. Green                                  0.97495
#   lawrence w green is best known by health education researchers as the originator of the pr
#   ecede model and codeveloper of the precedeproceed model which has
# * James A. Joseph                                    0.97506
#   james a joseph born 1935 is an american former diplomatjoseph is professor of the practice
#    of public policy studies at duke university and founder of
# * Timothy Luke                                       0.97584
#   timothy w luke is university distinguished professor of political science in the college o
#   f liberal arts and human sciences as well as program chair of
# * Archie Brown                                       0.97628
#   archibald haworth brown cmg fba commonly known as archie brown born 10 may 1938 is a briti
#   sh political scientist and historian in 2005 he became
# * Jerry L. Martin                                    0.97687
#   jerry l martin is chairman emeritus of the american council of trustees and alumni he serv
#   ed as president of acta from its founding in 1995
# * Ren%C3%A9e Fox                                     0.97713
#   rene c fox a summa cum laude graduate of smith college in 1949 earned her phd in sociology
#    in 1954 from radcliffe college harvard university
# * Robert Bates (political scientist)                 0.97732
#   robert hinrichs bates born 1942 is an american political scientist he is eaton professor o
#   f the science of government in the departments of government and
# * Ferdinand K. Levy                                  0.97737
#   ferdinand k levy was a famous management scientist with several important contributions to
#    system analysis he was a professor at georgia tech from 1972 until

# %%
# Bipartition the cluster of non-athletes
left_child_female_non_athletes, right_child_female_non_athletes = bipartition(female_non_athletes, maxiter=100, num_runs=6, seed=1)
# Out:
# Initialization complete
# Initialization complete
# Initialization complete
# Initialization complete
# Iteration  0, inertia 44853.060
# Iteration  0, inertia 44679.078
# Iteration  0, inertia 44839.016
# Iteration  0, inertia 44467.930
# Iteration  1, inertia 22445.702
# Iteration  1, inertia 22393.793
# Iteration  1, inertia 22437.377
# Iteration  1, inertia 22429.320
# Iteration  2, inertia 22407.887
# Iteration  2, inertia 22416.328
# Iteration  2, inertia 22366.020
# Iteration  2, inertia 22418.303
# Iteration  3, inertia 22393.069
# Iteration  3, inertia 22404.650
# Iteration  3, inertia 22358.156
# Iteration  3, inertia 22414.452
# Iteration  4, inertia 22380.942
# Iteration  4, inertia 22402.987
# Iteration  4, inertia 22357.405
# Iteration  4, inertia 22409.087
# Iteration  5, inertia 22372.280
# Iteration  5, inertia 22402.806
# Iteration  5, inertia 22357.315
# Iteration  5, inertia 22403.931
# Iteration  6, inertia 22363.775
# Iteration  6, inertia 22357.305
# Iteration  6, inertia 22402.770
# Iteration  6, inertia 22400.398
# Iteration  7, inertia 22358.434
# Iteration  7, inertia 22357.302
# Iteration  7, inertia 22402.757
# Iteration  7, inertia 22397.620
# Iteration  8, inertia 22357.419
# Iteration  8, inertia 22357.302
# Converged at iteration 8: center shift 0.000000e+00 within tolerance 1.793546e-10
# Iteration  8, inertia 22402.751
# Iteration  8, inertia 22393.691
# Initialization complete
# Iteration  9, inertia 22357.316
# Iteration  9, inertia 22402.749
# Iteration  0, inertia 44471.094
# Iteration  9, inertia 22384.696
# Iteration 10, inertia 22357.304
# Iteration 10, inertia 22402.748
# Iteration  1, inertia 22391.077
# Iteration 10, inertia 22366.276
# Iteration 11, inertia 22357.302
# Iteration 11, inertia 22402.747
# Iteration  2, inertia 22366.353
# Iteration 11, inertia 22357.650
# Iteration 12, inertia 22357.300
# Iteration 12, inertia 22402.747
# Iteration  3, inertia 22357.633
# Iteration 12, inertia 22357.334
# Iteration 13, inertia 22357.300
# Converged at iteration 13: center shift 0.000000e+00 within tolerance 1.793546e-10
# Initialization complete
# Iteration 13, inertia 22402.746
# Iteration  4, inertia 22357.336
# Iteration 13, inertia 22357.304
# Iteration  0, inertia 44631.006
# Iteration 14, inertia 22357.300
# Iteration  5, inertia 22357.310
# Iteration 14, inertia 22402.746
# Iteration  1, inertia 22428.715
# Iteration 15, inertia 22357.299
# Converged at iteration 15: center shift 0.000000e+00 within tolerance 1.793546e-10
# Iteration  6, inertia 22357.303
# Iteration 15, inertia 22402.746
# Iteration  2, inertia 22385.193
# Iteration  7, inertia 22357.301
# Iteration 16, inertia 22402.745
# Iteration  8, inertia 22357.301
# Converged at iteration 8: center shift 0.000000e+00 within tolerance 1.793546e-10
# Iteration  3, inertia 22371.704
# Iteration 17, inertia 22402.744
# Iteration  4, inertia 22363.676
# Iteration 18, inertia 22402.744
# Iteration  5, inertia 22358.556
# Iteration 19, inertia 22402.743
# Iteration  6, inertia 22357.421
# Iteration 20, inertia 22402.743
# Converged at iteration 20: center shift 0.000000e+00 within tolerance 1.793546e-10
# Iteration  7, inertia 22357.317
# Iteration  8, inertia 22357.305
# Iteration  9, inertia 22357.302
# Iteration 10, inertia 22357.301
# Converged at iteration 10: center shift 0.000000e+00 within tolerance 1.793546e-10

# %%
display_single_tf_idf_cluster(left_child_female_non_athletes, map_index_to_word)
# Out:
# zwigoff:0.027 zwacksalles:0.023 zupanprofessor:0.017 zulfiqar:0.016 zuppiger:0.015
# * Julian Knowles                                     0.96904
#   julian knowles is an australian composer and performer specialising in new and emerging te
#   chnologies his creative work spans the fields of composition for theatre dance
# * Peter Combe                                        0.97080
#   peter combe born 20 october 1948 is an australian childrens entertainer and musicianmusica
#   l genre childrens musiche has had 22 releases including seven gold albums two
# * Craig Pruess                                       0.97121
#   craig pruess born 1950 is an american composer musician arranger and gold platinum record
#   producer who has been living in britain since 1973 his career
# * Ceiri Torjussen                                    0.97169
#   ceiri torjussen born 1976 is a composer who has contributed music to dozens of film and te
#   levision productions in the ushis music was described by
# * Brenton Broadstock                                 0.97192
#   brenton broadstock ao born 1952 is an australian composerbroadstock was born in melbourne
#   he studied history politics and music at monash university and later composition
# * Michael Peter Smith                                0.97318
#   michael peter smith born september 7 1941 is a chicagobased singersongwriter rolling stone
#    magazine once called him the greatest songwriter in the english language he
# * Marc Hoffman                                       0.97356
#   marc hoffman born april 16 1961 is a composer of concert music and music for film pianist
#   vocalist recording artist and music educator hoffman grew
# * Tom Bancroft                                       0.97378
#   tom bancroft born 1967 london is a british jazz drummer and composer he began drumming age
#   d seven and started off playing jazz with his father

# %%
display_single_tf_idf_cluster(right_child_female_non_athletes, map_index_to_word)
# Out:
# zwolsman:0.124 zx10r:0.092 zwacksalles:0.015 zongkar:0.015 zwigoff:0.014
# * Janet Jackson                                      0.93374
#   janet damita jo jackson born may 16 1966 is an american singer songwriter and actress know
#   n for a series of sonically innovative socially conscious and
# * Barbara Hershey                                    0.93507
#   barbara hershey born barbara lynn herzstein february 5 1948 once known as barbara seagull
#   is an american actress in a career spanning nearly 50 years
# * Lauren Royal                                       0.93717
#   lauren royal born march 3 circa 1965 is a book writer from california royal has written bo
#   th historic and novelistic booksa selfproclaimed angels baseball fan
# * Alexandra Potter                                   0.93802
#   alexandra potter born 1970 is a british author of romantic comediesborn in bradford yorksh
#   ire england and educated at liverpool university gaining an honors degree in
# * Cher                                               0.93804
#   cher r born cherilyn sarkisian may 20 1946 is an american singer actress and television ho
#   st described as embodying female autonomy in a maledominated industry
# * Madonna (entertainer)                              0.93806
#   madonna louise ciccone tkoni born august 16 1958 is an american singer songwriter actress
#   and businesswoman she achieved popularity by pushing the boundaries of lyrical
# * Jane Fonda                                         0.93836
#   jane fonda born lady jayne seymour fonda december 21 1937 is an american actress writer po
#   litical activist former fashion model and fitness guru she is
# * Ellina Graypel                                     0.93927
#   ellina graypel born july 19 1972 is an awardwinning russian singersongwriter she was born
#   near the volga river in the heart of russia she spent

# %% [markdown]
# **Quiz Question**. Let us bipartition the clusters `male_non_athletes` and `female_non_athletes`. Which diagram best describes the resulting hierarchy of clusters for the non-athletes? Refer to the quiz for the diagrams.
#
# **Note**. Use `maxiter=100, num_runs=6, seed=1` for consistency of output.
